# %% [markdown]
# <a href="https://colab.research.google.com/github/guipereira42/bootcamp-data-science-alura/blob/main/notebooks/bootcamp_data_science_aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação de bibliotecas utilizadas na primeira aula

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# Load do arquivo com tratamento de encoding, separador, remoção de linhas de cabeçalho e rodapé e tratamento de números

# %%
url = 'https://raw.githubusercontent.com/guipereira42/bootcamp-data-science-alura/6390b855d45ebb0e9b1235ecc2f3ebb976e0cca3/dados/A070231189_28_143_208.csv'

# %%
dados = pd.read_csv(url, encoding = "latin_1", skiprows = 3, skipfooter = 12, sep = ";", thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#   Unidade da Federação     2008/Jan  ...     2021/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10951319.46  1.073782e+09
# 1              12 Acre    902416.00  ...   4138751.64  4.752903e+08
# 2          13 Amazonas   4735529.42  ...  21752718.52  2.041004e+09
# 3           14 Roraima    657889.53  ...   3781921.16  3.493955e+08
# 4              15 Pará  18864744.11  ...  41160323.18  4.950136e+09
#
# [5 rows x 166 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2021/Ago         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  137579124.29  1.350319e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...   36433854.87  2.485179e+09
# 24         51 Mato Grosso   4795299.01  ...   36567362.69  2.356738e+09
# 25               52 Goiás  15310637.29  ...   68455250.62  5.311852e+09
# 26    53 Distrito Federal   4745919.19  ...   27288766.94  2.749947e+09
#
# [5 rows x 166 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 166 entries, Unidade da Federação to Total
# dtypes: float64(163), object(3)
# memory usage: 35.1+ KB

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan      15,126,846.64
# 2008/Fev      22,710,158.12
# 2008/Mar      24,594,187.35
# 2008/Abr      25,431,957.83
# 2008/Mai      26,511,245.91
#                  ...
# 2021/Abr      72,558,458.73
# 2021/Mai      76,781,349.18
# 2021/Jun      80,038,897.67
# 2021/Jul      78,895,881.06
# Total      6,774,438,510.94
# Length: 163, dtype: float64

# %%
dados['2008/Ago']
# Out:
# 0      3,231,494.61
# 1      2,089,107.14
# 2      9,352,532.70
# 3        894,271.18
# 4     23,341,218.03
# 5      1,475,551.38
# 6      5,413,710.38
# 7     15,195,312.89
# 8     10,549,176.40
# 9     27,851,438.72
# 10    10,640,817.47
# 11    12,872,578.37
# 12    35,457,038.66
# 13     9,373,432.00
# 14     5,238,398.50
# 15    46,931,248.28
# 16    84,722,528.10
# 17    12,588,595.77
# 18    50,912,706.60
# 19   184,854,516.35
# 20    56,982,774.90
# 21    31,250,854.33
# 22    56,113,054.70
# 23     9,671,553.45
# 24     9,243,148.81
# 25    20,650,730.67
# 26    13,710,857.89
# Name: 2008/Ago, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind = "bar", figsize=(18, 7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor de procedimentos hospitalares processados em Agosto de 2018 por UF")
plt.show()

# %%
dados = dados.replace("-", 0)
dados['2021/Ago'] = pd.to_numeric(dados['2021/Ago'])
dados = dados.sort_values(by=['2021/Ago'], ascending= False)
ax = dados.plot(x="Unidade da Federação", y="2021/Ago", kind = "bar", figsize=(18, 7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor de procedimentos hospitalares processados em Agosto de 2021 por UF")
plt.show()
